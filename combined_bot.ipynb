# %% [markdown]
# ### Install packages

# %% [markdown]
# ### Import libraries

# %%
import string
import random
import matplotlib
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from nltk import word_tokenize

# %% [markdown]
# ### Get SQuAD data from GitHub

# %%
csv_url = 'https://raw.githubusercontent.com/davisjrule/SQuAD-bot/main/train-squad.csv'
df = pd.read_csv(csv_url)
df.drop('id', axis=1, inplace=True)
df.drop('answer_start', axis=1, inplace=True)
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('context', axis=1, inplace=True)
df.rename(columns={"text": "answer"}, inplace = True)
df = df.iloc[0:500]

# %% [markdown]
# ### Get chat data from GitHub

# %%
csv_url = 'https://raw.githubusercontent.com/davisjrule/SQuAD-bot/main/topical_chat.csv'
df2 = pd.read_csv(csv_url)
df2.drop('conversation_id', axis=1, inplace=True)
df2.drop('sentiment', axis=1, inplace=True)

questions = df2[0:5000:2]
responses = df2[1:5000:2]

questions.head()

# create dataframe
data = pd.DataFrame()
data['question'] = df2[0:5000:2]
data['answer'] = df2[1:5000:2].values
data = data.iloc[0:700]
data = pd.concat([data, df])

data = data.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ### Process data

# %%
def clean_text(text):
  text = str(text).lower()
  text = text.replace("can't", "cannot")
  text = text.replace("won't", "will not")
  text = text.replace("i'm", "i am")
  text = text.replace("'ve", " have")
  text = text.replace("'ll", " will")
  text = text.replace("n't", " not")
  text = text.replace("'d", " would")
  text = text.replace("'s", " is")
  text = text.replace("'re", " are")
  for char in string.punctuation:
    if char != '-':
      text = text.replace(char, '')
  return text

# %%
pairs = list(zip(data['question'],data['answer']))
pairs
# Out:
# [('Beyonce joined 2 other women on what list from Billboard magazine in 2011?',
#   'Top 20 Hot 100 Songwriters'),
#  ('What was Angela Merkel serving as in relation to the letter?',
#   'the head of the G7 in Germany'),
#  ('When did Beyoncé begin to manage the girl group?', '1995'),
#  (" Before Google launched gmail, that was the name of a free email service offered by garfield's website. That actually seems more fun.",
#   ' I know now everytime I open gmail I think of garfield'),
#  (' I would do exactly the same as you.  How could you not pass that up the chance to set yourself up for life? lol',
#   ' Yeah, that is quite lucky. Do you follow softball at all?'),
#  ('How much did Beyonce raise for Obama at the 40/40 Club?', '4 million'),
#  ('Who reported Beyonce to e the top earning woman in music?', 'Forbes'),
#  (' Now that you mention it I do somewhat remember seeing how he did that. It was almost like a piece of metal that would lock into his shoe so he could almost lean 45 degrees. I believe he used it in the Smooth Criminal music video.',
#   ' Looked very cool, when he did it!  I heard somewhere that Tupac danced ballet.  Have you heard anything about that?'),
#  (' Eminem actually wanted to be a comic book artist. Kanye West is very strange and has a lot of strange ideas. ',
#   ' Yes he is. But he has done some good things like giving a mic to a fan in a wheelchair at his concert.'),
#  (' I guess it was being smuggled to the USA from Mexico.',
#   " ya I don't like that that makes me mad, do you have any pets? I guess In Japan there are more pets than there are kids under the age of fifteen"),
#  (' Tupac danced ballet in high school and ended up portraying the mouse king in a production of the nutcracker.',
#   ' I found interesting the concept with rotten tomatoes. Poor people'),
#  (" Hey how are you, can't believe that Georgia senator got arrested!",
#   ' She said she was peacefully chanting.'),
#  (' Yes it helped him smooth out his dance moves',
#   ' Nice. Do you like Shakespeare?'),
#  (' You have a great weekend too!',
#   ' Hi, how are you doing this fine evening?'),
#  (" I never knew that.  There hasn't been a US president who wasn't a Republican or Democrat since 1853.",
#   " That's a good thing! Did you know in 1957 President Harry Truman visited Disneyland and refused to be photographed on the Dumbo ride so he wouldn't be associated with the Republican Party?"),
#  (" I didn't know that.  Maryland's governor, Larry Hogan, is a republican who was under some hot water for policies on climate change.",
#   ' Thats interesting.  the beatles song"come together" was written for 1969 governor campaign.'),
#  ("Which song did Beyoncé release as the lead single for Austin Powers in Goldmember's soundtrack?",
#   'Work It Out'),
#  (' True.  I also heard that Hillary Clinton was president of the young republicans when she was in college.',
#   " Oh that's interesting especially given the fact that she just ran Democrat. The red and blue colors for Republicans and Democrats only started in 2000."),
#  ('Where did Beyonce release her 5th album to a huge surprise?',
#   'the iTunes Store'),
#  ('Who was the letter addressed to?',
#   'Angela Merkel and Nkosazana Dlamini-Zuma'),
#  (' I have. I heard that he started a library in 1895 with 32,000 books in it. All from his personal collection. Can you imagine?',
#   ' The more amazing thing to me is how he carted all those books by wheelbarrow over 3/4 mile. He was 85!'),
#  (" That's sad. About 71% of Earth's surface is covered with water.",
#   ' Also, When earth was first formed a day was only 5.5 hours long.  Such short days!  i wouldnt mind going to work for only 2 hours lol '),
#  (' Yes, it was until Jaws was released. That was a scary movie back in the day.',
#   ' Yeah, that was a good movie. Did you like it? '),
#  ('Beyonce tied who for most number one singles by a female?', 'Mariah Carey'),
#  (' Jupiter has a moon that could be considered a planet if it orbited the sun.',
#   " Wow that's crazy. Do you know much about governors?"),
#  (' Dogs are my favorite also.  I hope to get another one in the future.',
#   ' Do you have any now?  I have two.'),
#  (" I think it's fun to read sometimes. The origins are more interesting for me. Early poems in the Eurasian content evolved from folksongs. ",
#   ' I dont much about poetry. that is interesting. i guess poetry and songs would be closely related.'),
#  ('What did Beyoncé and Jay Z name their daughter?', 'Blue Ivy Carter'),
#  ("Destiny's Child song, Killing Time, was included in which film's soundtrack?",
#   'Men in Black.'),
#  ('In what city and state did Beyonce  grow up? ', 'Houston, Texas'),
#  (" Wow, I'm surprised they have such similar voices. I went the Sega to Playstation route, still rocking the PS4, no Toy Story game though.",
#   " Yeah the PlayStation 4 is cool. I'm just glad that we called him video games and not their original name which was the cathode ray tube Amusement device LOL"),
#  (" I'm pretty sure that it has, I know that it made a ton of money. Apparently the villain used to sing that song I mentioned, Let It Go, but the song was so happy that they changed the character",
#   " that's good thinkg. I bet the song is up for an award somewhere. Who were the people involved in the film?"),
#  (" Maybe the Harry Potter movies? I don't think the movie Blade Runner comes close to it haha. Have you seen it?",
#   ' Yeah I have seen all the blade runner movies. They are very cool and gritty. Ridley Scott is a good director.'),
#  (' Really, very cool! I love to snorkel too! The coral reefs are so spectacular!!',
#   ' They really are! Well it was nice chatting with you have a good night!'),
#  (' I hope he did as well, the raven is like his most popular poem and selling it for $9, business was slow, he also wrote cyborg fiction,',
#   " That's pretty cool.  If he'd had a black character in it in the 1950s that was worthy of banning a science fiction comic!"),
#  (' That seems fun! That reminds me of the Anderson house bed and breakfast in Minnesota. They used to offer a free cat for the night when you booked a room.',
#   ' wow. there is a town in alaska where the mayor of the town is a cat'),
#  ('What did Beyonce call her first concert tour?', 'The Beyoncé Experience'),
#  ('Where was Beyonce when she became pregnant?', 'Paris'),
#  (' Wow, I bet that poem required a lot creativity, wrtting a poem with completely different meanings, oposing genres, genius',
#   ' There is one guy that wrote a poem of over 220 words in palindrome (where it is the same backwards and forwards -- like "nurses run")!'),
#  (' Yes, I agree. There is an extensive specialized vocabulary used to described equine-related concepts, covering everything from anatomy to life stages, size, colors, markings, breeds, locomotion, and behavior.',
#   " What do you think about sharks? Did you know they're sister species to rays?"),
#  (' Yeah I guess it must, because that is just way too high to just be chance. ',
#   ' did you hear that international electoral observers were blocked from polls in nine states in 2012'),
#  ('Rather than beats, what two things does Beyoncé usually come up with for producers?',
#   'melodies and ideas'),
#  ("What event caused Beyonce's depression?", 'split with Luckett and Rober'),
#  ("What was the name of Beyoncé's first international tour?",
#   'The Beyoncé Experience'),
#  ('Beyonce and Jay Z got a Guinness World record for what in 2009?',
#   'highest-earning power couple'),
#  (' Yes, Spidey is his favorite. My brother used to love Rugrats when he was little, I only found out recently, that Busta Rhymes voiced the reptar wagon in the movie.',
#   " I didn't know that either. That's pretty interesting. Did you know that Korean rappers invented a new type of freestyle?"),
#  ('What kind of music does Beyonce do?', 'R&B'),
#  ("Which film featured Destiny's Child's first major single?", 'Men in Black'),
#  ("Which single from B'Day was only released in the U.K.?", 'Green Light'),
#  ("It was announced that Destiny's Child would  disban in what European city?",
#   'Barcelona'),
#  ("What was the name of Destiny Child's third album?", 'Survivor'),
#  (' That is so cool how invlolved he is. I read that a movie named trojan wars costed $15,000,000 to make and only made $309. I need to find out what movie that is lol',
#   ' Wow what a loss, did you know Steven Spielberg still make millions from star wars because a bet from George Lucas in 1977?'),
#  (' Did you know North Dakotas governor declared martial law in 1934 and seceded from the U.S',
#   ' I did not know about this fact.  I am wondering if it is still in effect.  By the way, nice chatting with you'),
#  ('Where did Beyoncé get pregnant?', 'Paris.'),
#  (' Do you keep up with the election?', ' yeah, but moderately.  You?'),
#  (" Oh yeah? What an interesting person he must have been, in general! I don't even know what Javanese is , but apparently their alphabet when recited in order, is a poem. The ABC's are pretty poetic to me, now that we recite them so sing-songy.",
#   ' I wonder what kind of poems a computer could come up with? Computers do everything else, they can control microwave ovens, remote controls, robots...why not write poetry, right?'),
#  (' Hmm interesting one. DO you know what the Beatles song Come together was written for?',
#   ' Yeah it was for the California governor Timothy Leary in 1969'),
#  ('Beyonce was coached for her Spanish songs by which American?',
#   'Rudy Perez'),
#  (' I love the skits Saturday Night Live does of trump. The one of Brett Kavanaugh was hilarious, have you seen it?',
#   ' Yes it was hilarious! '),
#  (' Oh really, Wow! Did you know Clint Eastwood is allergic to horses, after riding all those horses in the movies?',
#   ' You would have never guessed since he rode like hundreds of them! He should have rode sharks instead!'),
#  ('When did she perform at the Roseland ballroom?', '2011'),
#  ('The Mamas members included which 3 musicians?',
#   'Montina Cooper-Donnell, Crystal Collins and Tiffany Moniqué Riddick'),
#  (" Hey what's up do use Google very often?I really love the company and was surprised to hear that it was founded back in 1998.",
#   ' i think everyone must use it daily! its become ingrained in every day life'),
#  (" I never met anyone with a tiger pet.  That is strange.  It's not legal to own pets in Boulder, Colorado but you can be their guardian.",
#   ' Lots of places have special animal rights. In 2002, germany became the first country in the world to universally give animals constitutionally-guaranteed legal rights.'),
#  ('The video for what song won Beyoncé the 2009 MTV Video of the Year award?',
#   'Single Ladies'),
#  (" They've got milky way bars, mars bars, and even jelly beans!",
#   " Wow, that's way cooler than the fact that they didn't let women wear pants until 1993."),
#  ('Beyonce was listed in 2011 as the highest paid performer per what?',
#   'minute'),
#  (' My son is, so I know a little bit about it.',
#   ' Nice!  Did you see the first movie when it came out in 1977?  I remember going to the theater to see it.'),
#  (' Yes. In fact, the what is seen as canonical depends on the traditions of different groups.',
#   ' That is what cuases disagreement between CHristian denominations about what should be included in the canon.'),
#  (" Hey there, heard anything interesting lately? I sure have, did you know Amazon contributed 38 billion to the city of Seattle's economy just by being there? ",
#   ' Hi, no I did not know. It looks like amazon means exciting news. They are now looking for a site for a second headquarters!'),
#  (" No I don't know, do you have any idea, if yes how much was the first purchase?",
#   ' Yeah it was for $27.95 and it was for the rights to name a building after themselves. '),
#  ('When did Beyonce have her first child?', 'January 7, 2012'),
#  (' Allergies can be serious to people.  I understand his reserve of having a cat.',
#   " Me too. A pet or companion animal is an animal kept primarily for a person's company, protection, or entertainment. No one should have to be made uncomfortable by a pet in the house."),
#  ('Beyoncé was the first female singer to headline what at the 2011 Glastonbury Festival?',
#   'Pyramid stage'),
#  (' Yes  I do. Did you know Bruce Lee was a cha cha dancer?',
#   ' Yes he even won a hardcore cha cha championship in 1958'),
#  ('Who suggested the hiatus for Beyoncé?', 'her mother'),
#  ('Who did Beyoncé part ways with during her hiatus?', 'her father'),
#  (' Dancing is a lot of fun. Did you know that Bruce Lee was a great dancer?',
#   ' I heard that, winning Cha Cha championships and everything!'),
#  (" I've never seen that movie. There are so many rip-offs these days.",
#   " It is a show on Netflix actually. The first season isn't that bad. "),
#  (" I have't either. At the premiere screening the sound cut out. But instead of booing, the audience member cheers and makes their own sound effects.",
#   " Well that was sure nice of them to do that, I'm sure Spielberg appreciated it!"),
#  ("What was Beyoncé's character called in Austin Powers in Goldmember?",
#   'Foxxy Cleopatra'),
#  (' I did not know the exact percentages.  Thanks for the info!',
#   ' On a sad note relating to those percentages....more than 80 percent of the earths natural forests have already been destroyed?'),
#  ("Beyonce's documentary movie was called what?", 'Life Is But a Dream'),
#  (' A lot of people think the OT was so much better than the prequels because of her influence.',
#   " Yeah it was because of her that so many major changes were made like Leia's good luck kiss, Obi Wan's death, etc. She was truly a big influence!"),
#  ("Who's death caused this protest?", 'Freddie Gray'),
#  ('When did Beyoncé release Formation?', 'February 6, 2016'),
#  (" That is probably a holdover from the old days when a player was chosen to be manager. Nowadays, it wouldn't work.",
#   ' Yes, I wonder if it could be even dangerous for some of them, like some could have an heart attack.  '),
#  (' I wonder if reptiles are considered ectothermic like most fish?',
#   ' That would be a good thing to know, especially because some of them make good pets.'),
#  ('I which church was Beyonce  a member and soloist  in the choir?',
#   "St. John's United Methodist Church"),
#  (" Yeah and saltwater fish are lucky because they can do that and drink through their mouth's.",
#   ' seems like fresh water fish got the short end of the stick with that one. Have you ever been to a cat cafe?'),
#  ('Who collaborated with Beyoncé on the single, Deja Vu?', 'Jay Z'),
#  ('When was 4 released?', 'June 28, 2011'),
#  (' It makes sense when you put it that way but in terms of that universe size the electron could be very big.',
#   ' Maybe they did mean to say that our universe is contained in an electron in another universe ?'),
#  ("Who was blamed for Luckett and Roberson leaving Destiny's Child?",
#   'Beyoncé'),
#  (" Haha! Woah! There's a thing called transhumanists I guess, and they want to upload their brains to computers and memory sticks! I don't want to do that! One lifetime is okay by me. I can only imagine the torment of a mind having to just live for possibly forever! Yikes!",
#   " I agree! What if people tried to read my mind's unpublished poetry! No thank you! I have some interesting fan fiction in my head, just like Julius Caesar wrote fan fiction of Hercules and Oedipus. But that's private!"),
#  ('When did she and Jay Z become the highest paid black celebrity couple?',
#   '2011'),
#  (' The compliment battle, lol. i would love to hear that. I love how people think the cowboy hat was the most popular in the old west, yet it was really the bowler.',
#   " Yeah, cowboy hats were more as working hats weren't they? Did you know that up until 1998 politicians had to wear a top hat if making a point of order in the House of Commons?"),
#  ('What song by Mariah Carey influenced her?', 'Vision of Love'),
#  (' Yep. And some become bigger hits than the movies, such as the soundtrack to "O, Brother, Where Art Thou?". It went octuple platinum.',
#   ' Alicia Keys wrote a song for the Men in Black soundtrack when she was only 16!'),
#  (" I agree too! I can't believe a michigan judge once delivered her ruling to eminem in the form of a rap haha.",
#   " That's kind of cool, I like it when people don't take themselves too seriously.  Like when Kanye made fun of himself on SNL.  If only he'd do it more."),
#  ('Beyonce confirmed what after performing one of her songs?',
#   'her pregnancy'),
#  (' That is awesome, I wonder why they settled on Earth.  It is the only one without a God/Goddess name.',
#   ' I saw that in 1975 the Soviet Union sent a spacecraft to Venus.'),
#  (" Must have paid pretty good otherwise I don't think they would have done it for that long.  A man found 3 million dollars worth of baseball cards in grandfathers attic that were hidden since the 1940's.  He hit the jackpot.",
#   ' Wow. I would probably sell some, and keep the rest as an investment. What would you do?'),
#  ('What song won Best R&B Performance in the 43 Annual Grammy Awards?',
#   'Say My Name'),
#  (' Hello.  Did you know that there is a candy desk in the us senate?',
#   " haha yeah, I heard about that. It's been there since 1968."),
#  (' He was the terminator! That is all he needed! lol',
#   ' yeah, the governator. he was not a good speaker but people knew him. he didnt get much done because he didnt understand politics.'),
#  ('Beyonce released the song "Formation" on which online music service?',
#   'Tidal'),
#  ('What is included at the end of Glory?', "Blue Ivy's cries"),
#  ('Where did Beyonce get her name from?', "her mother's maiden name"),
#  ('Who does Beyoncé feel is an all-around entertainer?', 'Diana Ross'),
#  (" I remember thinking just about everything in the prequels' timeline was off, based on the mental version of the past the OT led us to construct. But I'd have to rewatch to nail it down.",
#   " Yeah I would have to watch it as well! So are you also a fan of Chewbacca? I love him. I think it's funny there's a bat species called the Chewbacca bat. That's hilarious!"),
#  ('What language does she mainly sing?', 'English'),
#  ('When did the tour begin?', 'April 15'),
#  ('In which years did Time rate Beyonce in the 100 most influential people in the world?',
#   '2013 and 2014'),
#  (' Interesting.  Do you ever vote for the governor in your state?  I do.',
#   ' I do. Can you believe when Arnold Schwarzenegger was governor of CA he never lived in Sacramento, instead he commuted 3 hours every day by private jet.'),
#  ('Jay Z has a website called what?', 'Lifeandtimes.com'),
#  ('Who did Beyoncé tour with for the Verizon Lades First Tour?',
#   'Missy Elliott and Alicia Keys'),
#  (' I wonder if they met how that would go from there',
#   ' Yeah interesting point. Nice chat'),
#  ('For what network, did Beyonce land a major movie role in?', 'MTV'),
#  (' Yes, I think that was good for the USPS!  How would you like to have a building named after yourself for being a customer and only spend $27.95?',
#   " If only I knew about it years ago!!!!! I didn't realize they own IMDB as well!"),
#  (' I have heard about that.  One of the senators tried to escape and was carried feet first into the senate chamber by three officers!',
#   " Yeah, I think that rule might be from before senators were elected. They weren't elected until 1913."),
#  ('What did she sing at the 2009 Presidential Inauguration?',
#   'America the Beautiful'),
#  (" Hi! Hm. I don't read much fiction or poetry, but I've been exposed to a lot of it in my lifetime. Do you have any favorites? I've tried my hand at creating both, and failed miserably! It's tough! It's an art form, that I just can't do!",
#   " I've been more into poetry lately. It's fascinating that it's been around since prehistorical times, with hunting poetry in Africa. "),
#  (' I know, Also, I do believe in Japan there is less people under 15 years of age than pets.',
#   ' do you know how many idnividual animals are believed to be on earth?'),
#  (" yes, it was great movie. And there's a sequel coming out. I can't wait!",
#   " Hahaha, liked the graphics, tooo!  Do you like dogs? I didn't know that among dogs they have 12 different blood types!!!!!!!"),
#  ('What number was Beyoncé on the Top 20 Hot 100 Songwriters list?', '17'),
#  (' Right? I wonder who built it too? I wish my son could do that stuff. But not smoking. Smoking near an apple computer voids the warranty.',
#   ' Good thing I never smoked near mine.  They think it makes it a "biohazard"'),
#  ('Who listed her at number 17 in their list of  Top 20 hot 100 Songwriters?',
#   'Billboard magazine'),
#  ('The single, "Listen" was featured in which movie?', 'Dreamgirls'),
#  (' Would you like to  see a film with Chewbacca as the principal character ? ',
#   ' I think it would be interesting. There are also so many comic stories that could be told. I just wonder how communication would work in such a movie'),
#  ('How many people watched the 2011 MTV Video Music Awards?', '12.4 million'),
#  ('What does she get credits for in her music?', 'co-producing credits'),
#  (' I heard about it and we need to do something about it.  ',
#   " I agree.  It's sad.  I had a good time chatting with you tonight!"),
#  ('"Charlie\'s Angels" featured which single from the band members?',
#   'Independent Women Part I'),
#  (' I think so. Apparently she was the first female director of a film that earned over 1 billion dollars too. So that is another record that she set',
#   " Disney has won a ton of awards, and I'm sure she'll win awards as well."),
#  ("Who helped Beyoncé overcome her depression during the years following the Destiny's Child split?",
#   'her mother'),
#  (' Yes, and zebrafish are very interesting.',
#   ' yeah did you know we use them to figure out stufffor ourselves'),
#  (" I saw that they are using a surrogate and only paying 70k.  I'd want a whole lot more than that!",
#   " ok, yes that's what I read... and somebody needs to explain to me, how using a surrogate really works..."),
#  (' Many are adopting the kids because they want to give them safe homes!',
#   ' Oh, then, thank you very much. Glad to know about this. God bless them. Well, I liked a lot Frozen. Is a fiery Princess.'),
#  (' Seems like Steven Spielberg is trying to return to his glory with Ready Player One. Have you seen that?',
#   " No, I haven't see it.  Have you?"),
#  (' Did you hear that Texas had a female governor before other states even allowed women to vote?',
#   ' Yeah thats really interesting. did you know there hasnt been a us president who wasnt a rep or dem since 1853?'),
#  ("Beyoncé was a featured artist on which singer's hit, Telephone?",
#   'Lady Gaga'),
#  ('When did Beyonce get her fifth consecutive number one hit album?',
#   'December 13, 2013'),
#  (' Speaking of cats, I would love to get a glow in the dark one. They have those in South Korea.',
#   ' Wow. In Japana and Taiwan there are cat cafes where you can play with them'),
#  (' Yes including german, spanish, italian, and french. Amazing',
#   ' I know. The track title in the Batman Begins ST is named after a genius of a bat'),
#  (" Me neither, I wish I knew more about the olympians, they're so elite. Hard for them to get a lot of recognition though. You play video games by chance?",
#   " Yes I play video games somewhat, used to play Maurice a kid but I don't play that many these days. What about you? I'm just glad that I didn't grow up in South Korea because apparently playing a video game after midnight if your under 16 is illegal"),
#  (" I couldn't have said it any better lol. That was such an odd meeting between them two a couple months ago!",
#   ' I recall the time that Kanye stood up to a President when he perceived racism, now he seems to have flipped.  I guess they money makes a big difference,'),
#  (' No, I did not.  My son went with his friends. Apparently, Star Wars was dubbed in Navajo in 2013.',
#   " There must have been a big enough market for them to do that.  They have the money to do it that's for sure.  Just the box office alone the Star Wars franchise has brought in over $8.5 billion dollars!"),
#  (' Did you ever hear of people being contacted due to DNA matches?  You can opt in or out but might be connected with matches of family members',
#   ' That is pretty cool. There are several companies offering DNA testing, and each seems to offer a different way of handling client privacy'),
#  (" I don't know but I am at the end of knowledge on this subject. What do you think about the facts of comics? I would have thought US invented them, but it's Japan or UK.",
#   ' Japan has a great printing history, I am not surprised about this. Do you read comics books ? I have read a few but not about super-heroes. '),
#  (' Ancient Athens did their appointment by lottery instead of election.',
#   ' It is weird, but true'),
#  (' Yes, did you know seahorses only fish to have a neck?',
#   ' that is so cool, and the males carry the young in that species'),
#  (' That is true.  Did you know that the taller candidate has won the presidential election 75% of the time?',
#   ' hahaa I really wonder if that has any correlation with how people perceive the candidates'),
#  (' Haha! I am quite happy keeping my thoughts to myself! It sounds like a scary sci-fi movie to me! My computer brain gets arrested and imprisoned for eternity in 100 years for some crazy new law! No thank you!',
#   ' How much memory would it take to store all of us, anyway? Maybe less than I think. A space shuttle can run on 1mb of RAM. '),
#  ('Which organization did Beyoncé donate her pay for the private performance to?',
#   'Clinton Bush Haiti Fund.'),
#  (" I used to have a collie named Bimbo.  That's a great question.",
#   ' Mine is named Cute Stuff.  Did you know about the fish that lives on land? I wonder what it is.'),
#  ("Beyonce's younger sibling also sang with her in what band?",
#   "Destiny's Child"),
#  ('An example of a song aimed towards a male audience is what?', 'Cater 2 U'),
#  (' Are you interested in dogs? They are quite clever. Dogs can learn over a thousand words and  reason better than chimps.',
#   ' Yes! I sometimes Love them better than people... they are just full of Love. Did you know there are 12 different blood types that a dog may have and dog can donate blood at dog blood drives! I love them even more!'),
#  ('When did Destiny\'s Child release its album "Love Songs"?', 'January 2013'),
#  ('Which famous landmark did Beyonce see in China?',
#   'the Great Wall of China'),
#  (' lol, I know, I guess  the US have more tigers as pets than living wild in Asia.',
#   ' and Roosevelet did not have any of them'),
#  (" Haha. Funny. I don't eat seafood. My mom forced me to eat salmon way too often when I was little and I grew sick of it. Haha #firstworldproblems.",
#   ' haha ya, well I am like the black swallower fish, I could eat a salmon twice my height and ten times my weight because I love it'),
#  ('What was the first album Beyoncé released as a solo artist?',
#   'Dangerously in Love'),
#  (' I know. It is so surprising to me that it took that long for two women senators to protest by wearing pants on the senate floor.',
#   ' They wore pantsuits, they kept it classy. haha.'),
#  ('Beyonce voiced a character in which animated film?', 'Epic'),
#  (' Yeah same to you, good chat.', ' bye!'),
#  ('When did Beyoncé rise to fame?', 'late 1990s'),
#  (' I have not seen the movie. Is it animated? Is it for kids?',
#   ' both! lol, although Im not a kid so I guess for all haha, I did take my kids to see the movie though. It came out in 2013 and earned over 1 billion dollars'),
#  (' No, But I did not know they were first designed for the military',
#   " It could be for training purpose. I'm wondering why Australia has more banned games than China... It means some US games also banned... It's quite strange. "),
#  (' Did you know Google had hundreds of live goats to cut the grass in the past? ',
#   ' It is very interesting. Google provide "Chrome OS" which is a light weight OS. Google provided a lot of hardware mainly in 2010 to 2015. '),
#  (" I didn't know this thanks for sharing.",
#   " Sure thing!  Did you hear about Michael Jackson's special patent shoes?"),
#  (" No I didn't hear that, I wonder why they stopped doing that? ",
#   ' maybe they did not trust them, i have no idea. do you know when republicans and democrats started using red and blue?'),
#  (" I didn't know that either. That has to sound a lot different than the rap battles here. It was nice talking with you as well. ",
#   ' Yes here they are much more agressive! Have a good one!'),
#  (" lol, I agree with you!! I didn't know Nevada is the only state to have a none of the above voting option?",
#   ' I think that is a perfect option.  Sometimes there just arent good candidates.'),
#  (" Wow, I didnt realize it was really that far away.  Does that include pluto, they can't decide about that poor planet.",
#   ' I believe it does. There is a planet that orbits four stars.'),
#  (' Well elections also lead to a dog being elected mayor... so I dont know what is worse.',
#   ' Haha yes good point. I hope that one day the voter turnout for presidential elections will breach 63%.'),
#  (' Haha that is super creative. Do you ever read movie reviews?',
#   ' I read them sometimes, I mostly rely on Rotten Tomatoes, and you?'),
#  (' Must have been an absentee ballot!  ',
#   " It's been fun chatting,  have a good one. "),
#  (' Yeah true. Did you know babies are really good at dancing?',
#   ' Yes and they smile more when they hit the beat'),
#  ('For what does Beyonce receive praise?', 'stage presence'),
#  (' Yeah it does feel late, you are right. Did you hear about Truman and his refusal to take a photo on the dumbo ride?',
#   ' Yeah he just id not want to be associated with Republicans in any way, shape or form and the dumbo is their logo'),
#  (" Oh yeah I guess so ha ha. There's even a town in Alaska that has a mayor cat.",
#   ' Hi!  do you like to dance?'),
#  ('Where did Beyoncé perform for four nights of standing room only concerts in 2011?',
#   "New York's Roseland Ballroom"),
#  (' I heard that Netflix is losing a lot of money because of password sharing. Did you know Tom Hanks is the highest all-time box office star? I would believe it.',
#   ' Yeah, that could be, they are creating a lot of their own content. '),
#  (' I knew it was perhaps the most sold and published book of all time',
#   ' Yes. Prior to 1963 it was not uncommon for students in the US to be required to read from the bible as part of their elementary eduction!'),
#  (' Stephen Fry from Top Gear?',
#   " I'm not sure if it's the same guy, I don't know Top Gear personally, but it could be, do you ever play softball by the way or watch it on TV?"),
#  (' No, I do not.  I am actually allergic to cats.  The first cloned pet was a cat and its name was copy cat',
#   " That's interesting and a little funny.  I had no idea of this, but the cat is the most popular pet in the world.  DId you know that?"),
#  (' Hello, do you follow politics much?',
#   ' Hi I do from time to time, it is hard to escape them all together. Did you know every republican president has had a beard? '),
#  (' That sounds really racist, theres a wiki rank of fictional characters according to power and abilities,  I wonder who is the strongest hero',
#   ' Maybe like a Superman type or Hercules?  Funny thing, future emperor Julius Caesar actually wrote Hercules based fan fiction when he was younger.  I wonder what that was like.'),
#  (" Yeah, can't make good choices when your sugar has dropped!  It can't believe it took until 1993 for women to wear pants on the senate floor. ",
#   ' I know.  If I were elected, I would be doing that first day.  Actually, Id probably bring up senate pajama day.  I m all about the comfort.'),
#  ('When did Beyonce sign a letter for ONE Campaign?', '2015'),
#  ("Who decided to place Beyonce's group in Star Search the talent show?",
#   'Arne Frager'),
#  ("who talked about Beyonce's tone and timbre as distinctive?", 'Jody Rosen'),
#  (" No.  Not enough fans to support it. lol  Jose Canseco claims to hold the record for longest softball homerun at 622 feet.  He might have it.  I've watched him hitting softballs on youtube.  He crushes them even still to this day.",
#   ' He had the juice to hit the balls a country mile. I didnt know he played softball. '),
#  ("What race was Beyonce's father?", 'African-American'),
#  (' Yes it only takes about 6 years, and give great classical dressage performances!',
#   " I would love to see them in real life! I'm good with sharks though although I just snorkeled with some last month!"),
#  ('How many albums did Beyonce sell in the first week when she released her second album?',
#   '541,000'),
#  (' Good morning.', ' good morning'),
#  (' Yes I bet superman is up there. Probably Thor too. Julius Caesar wrote fan fiction of Hercules in his youth. He definitely got started early.',
#   ' Superman definitely has to be up there if not number one. Well nice chatting with you!'),
#  (' did you see that Kanye is having another kid?',
#   " I heard something but I'm not really following his offspring :)"),
#  (' Do you follow politics?',
#   ' I do. I just learned that the Republican Party was founded by anti-slavery activists. Surprising.'),
#  ('An important UN summit took place when?', 'September 2015'),
#  (" No. I know that Michael Jackson was a fantastic dancer but can you tell me more about his patent shoes if you don't mind.",
#   ' There was a specific device in his shoes that helped with his extreme lean in some dance moves.'),
#  (' Yes mine hurts just thinking about it. Edgar Allan Poe is another classic poet and he only received $9 for the publication of his poem the Raven.',
#   ' He probably spent it on drugs and booze too. the man was so decadent, but maybe it inspired him.'),
#  (" They did that, so they wouldn't be used as weapons. Smart move.",
#   " Yeah it is. I'd hate to be stabbed to death with a hat pin. "),
#  (' I did not. That sounds interesting. Much like the "tip of the hat" originates from Knights raising their visors.',
#   ' That is interesting too. I heard that in 1908 a law was passed limiting the length of hatpins.'),
#  ('What themes were influenced by her acting role in Dreamgirls?',
#   'feminism and female empowerment'),
#  ('How many awards was Beyoncé nominated for at the 57th annual Grammys?',
#   'six'),
#  ('How long was Beyonce depressed?', 'a couple of years'),
#  ('How many awards was Beyonce nominated for at the 52nd Grammy Awards?',
#   'ten'),
#  (' It really is, it was my favorite as a kid, much to the detriment of my parents.  LOL',
#   ' Haha thats funny. Apparently officials in ancient athens were appointed by lottery because they believe elections would lead to oligarchy.'),
#  ('How many Tweets per minute did the half time show get?',
#   '268,000 tweets per minute'),
#  (" LOL yep you don't want to be around an angry tiger mom haha. I guess they found one on the southern Border in Texas, a bag with a baby tiger that is",
#   ' Was it a smuggling thing?'),
#  (' every show played on TV, always wonder how dolphins kill sharks? I notice dolphins always attack from the side.',
#   ' Yeah I think you are right on that.  Dolphins are so interesting to me on how they communicate with each other. '),
#  (' That\'s pretty wild. Marvel published a "generic comic book," in order to trademark the names "superhero" and "super-villain." That was pretty smart of them. ',
#   ' No doubt!  Do you know much about the planets or the universe?'),
#  (' I know right? I hope that the dogs get a treat at least haha. Did you know that Istanbul has vending machines that reward stray dogs for bringing back trash?',
#   ' The Turks know the value of recycling and that dogs are keen to help for reward.'),
#  ("What city was Beyoncé's elementary school located in?", 'Fredericksburg'),
#  (' Absolutely, There are about 20 quintillion individual animals on planet earth.',
#   ' And who knows how many that are undiscovered.  Animals are truly fascinating!'),
#  ('Where was the album released? ', 'the iTunes Store'),
#  ('Who does Beyoncé describe as lyrical and raw?', 'Jean-Michel Basquiat'),
#  ('What song did Beyoncé perform at the 2009 inauguration of Obama?',
#   'America the Beautiful'),
#  ('What mental health issue did Beyonce go through?', 'depression'),
#  (' I have heard of it. Do you?',
#   " I like, the sport but there is not MLB team in my city, so I don't watch it. But I find it really interesting, full of small details, like managers wear a uniform so they could replace a player if they need to. "),
#  (" I did not know that, but that's interesting. I didn't know congress has played a democrat vs. republican baseball game every year since 1909. ",
#   ' I did, it must be one boring game! '),
#  (" Hm.. Yeah I know that smoking near them, just really clogs everything up, kind of taking dust and mixing it with the tarry nicotine and it creates a huge mess and can break a computer and completely stop the fans and such, but bio-hazard? I'm interested to learn why that is. Kinda scary!",
#   ' Someone built a working 16 bit computer using nothing but the basic Minecraft building blocks. I wonder what kind warranty that one has?!'),
#  ('Where did Beyonce become pregnant?', 'Paris'),
#  (" That's good and definitely practical. The author of game of thrones despises fan fiction because he says it is copyright infringement and not a good exercise for aspiring writers. I kind of see where he's coming from.",
#   " the fans should try to write their own stories, not rehash someone else's. "),
#  (' Yes, because they did not want to pay additional directing fee to Lucas. ',
#   ' Nice.  He scored then big time because the entire Star Wars franchise is estimated to $65 billion dollars!'),
#  ('How long did the hiatus last?', 'nine months'),
#  (' Amazon is a super large company, did you know chief executive own the Washington Post?',
#   " No I didn't know that.  Do you know how much the first ever Amazon purchase was for?"),
#  (' Yes but they changed it because feminine titles do not seem to do well, so sad',
#   ' That is sad and it is just the mentality that we have to work hard to change'),
#  ('When did Beyoncé become the highest paid black musician, ever?',
#   'April 2014.'),
#  ('Suga Mama is also a song on which Beyoncé album?', "B'Day"),
#  (" It's ironic that Walt Disney was fired from his job at a local newspaper in Missouri for ''not being creative enough.'' I guess his genius was not recognized because he was ahead of his time.",
#   " Wow! well see, that's why I believe in perfect timing sometimes there are better opportunities ahead of us. amazing! "),
#  ('Where was Beyonce quoted as saying that she is a modern-day feminist?',
#   'Vogue'),
#  (' Poetry is an art that is getting forgotten',
#   " It is one of those that I feel like I don't always understand, but love to hear the analysis of and see how deep it can get.  For instance, there is a poem where if you read it one way it's sad, but read it in reverse and it's actually inspirational!"),
#  (' Ha ha that is very important information I need to know too! Have a good afternoon.',
#   ' Hello there, do you use Amazon?'),
#  (' Hi!  How much do you know about planets? ',
#   ' Hello - I know the alternate names for Earth are gaia, tellus, and telluris.'),
#  ('Beyoncé used words from which Nigerian author in her song, Flawless?',
#   'Chimamanda Ngozi Adichie'),
#  ("What was the name of Beyoncé's European start that started in November 2003?",
#   'Dangerously in Love Tour'),
#  (" I think that is the strangest fact of the day.  I think it's wild when observers have to be blocked from polls during elections. ",
#   ' Strange and freaky! dian government sets up a polling booth in a forest full of lions for a single voter.'),
#  (" That's great! They also have 'eureka moments' and enjoy the experience of solving a problem  to obtain a reward. Much like people!",
#   ' Yes and they understand by pointing! How cool is that? Thats how I get my dog to get my slippers! Anyway, fun chatting with you! Namaste :)'),
#  ('How many dates did the Mrs. Carter Show World Tour have?', '132'),
#  (' I heard about it.  She was talented.  By the way,  Marcia is no longer married to Lucas.',
#   " Whoa!  I didn't know that.  Maybe George doesn't have as much as that $65 billion as I thought.  Yikes."),
#  (" Oh it's fascinating, for sure! Even more so to me since it eludes my abilities. heh. I've read that there is a poem which when read forwards is depressing, and when read backwards is inspiring! I'd really like to read it, but I can't find anything more about it, as of yet.",
#   ' That is fascinating. Similarly, Demetri Martin once wrote a 224 word palindrome poem. '),
#  (" Hello! I do like Star Wars! I can't believe companies thought it would be a flop!",
#   ' Yeah can you believe that? Now the franchise of Star Wars is estimated to be worth $65 billion.'),
#  ('Beyonce received how many nominations at the 52nd Annual Grammy Awards?',
#   'ten nominations'),
#  ("Which song did Beyonce sing at the first couple's inaugural ball? ",
#   'At Last'),
#  (' Yeah. its funny that he made all these movies here for all humans to see. Here on planet earth. A 4.5 million year old rock. I wonder if aliens seen our movies? ',
#   ' yes you are right, I really like all the Jurassic Parks, I have watched those movies several times.'),
#  (" I think it's funny when comedians do poetry. I don't really have a favorite poet. Demetri Martin wrote a 224 word palindrome!",
#   ' that must have taken him quite a while. 224 words, backwards and forwards? my head hurts.'),
#  (' I guess it was about Hercules and Oedipus. George RR MArtin would not have liked that!',
#   ' Yeah, he things it is copyright infringement.  I dont exactly agree with that.'),
#  (" Yeah I don't think that would work very well, but then again, maybe it would work better, who knows. ",
#   ' yeah there is no knowing there. In Nevada they have a none of these candidate options in the ballot.'),
#  ('Time magazine named her one of the most 100 what people of the century?',
#   'influential'),
#  ("Where did she perform wearing Baker's hula skirt?",
#   '2006 Fashion Rocks concert'),
#  ("What was Beyoncé's first concert?", 'Michael Jackson'),
#  ('What campaign did she contribute to?', 'Ban Bossy'),
#  (' Funny. I would love to learn more about a jellyfish that is immortal.',
#   ' I know they need to apply those genes to me! also weird is there is no fish except for the seahorse that has an actual neck'),
#  (' I agree! What kind of music do you like to listen to?',
#   " I'm a kid of the eighties and nineties,  I never really moved on from that alternative rock scene."),
#  (" I just don't care for him. I would have loved to have been in the courtroom, the day a judge decided to give her ruling to Eminem, in rap style.",
#   ' That would have been funny. Speaking of Eminem, did you know that his true dream was to become a comic book artist?'),
#  ('What choir did Beyoncé sing in for two years?',
#   "St. John's United Methodist Church"),
#  (" That's probably because they evolved earlier than Dinosaurs, nature's perfect killer!",
#   ' Crazy! there a very small ones. there is one called small dwarf lantershark. and it has a lenght of 17 cms. well it was so nice talking to you!!'),
#  ('When did she stop using her father as a manager?', 'During the break'),
#  (' Yes, I think it is the most effective search engine. How about you? Do you use gmail?',
#   ' Yes. a google search takes more computing power than sending astronauts tot he moon'),
#  (' Me too. Thanks for the informative chat.',
#   ' Hello, Did you know that there are over 1.5 million living animal species?'),
#  ("What did Beyoncé sing at President Obama's second inauguration?",
#   'the American national anthem'),
#  ('Beyonce supported which campaign that encourages leadership in girls?',
#   'Ban Bossy campaign'),
#  ('What song did Beyoncé release as the lead single from The Fighting Tempations?',
#   'Fighting Temptations'),
#  (' Haha I wonder if humans developed these white patches as well. What do you think about Germany giving constitutional rights to animals? They did that back in 2002',
#   ' I think German constitutional right for animals are pretty cool. Pretty, pretty . I learned about that while watching the German remake of the classic film, "12 angry hamsters"'),
#  (' I think so. I dont know if any green party have ever been elected. Did you know all presidents with beards have been republican.?',
#   ' Just know about this fact by now.  Which party do you think will win the next Presidential Electin?'),
#  (" Wow.  There are some crazy planets out there.  Venus doesn't even have seasons because it doesn't tilt and rotates in a different direction than the rest of the planets that revolve around our sun.",
#   ' That is really interesting. I heard that astronauts can vote from space, lol. '),
#  (' For sure, I would have voted for him if I was in california, even though he ruined the state. ',
#   ' people that should run government do not run for office. if they run for office, we probably dont want them in there.'),
#  ("Beyonce along with Jay Z met with whom's family after their death?",
#   'Freddie Gray'),
#  ("Beyonce's first solo album in the U.S. with what artist in the lead single?",
#   'Jay Z'),
#  ('What was the lead single for the Dreamgirls soundtrack?', 'Listen'),
#  ('What town did Beyonce go to school in?', 'Fredericksburg'),
#  ('Who was credited for her cries on the song?', 'B.I.C.'),
#  ('Beyonce got married in 2008 to whom?', 'Jay Z'),
#  ('Who did Beyonce perform with at Super Bowl 50?', 'Coldplay'),
#  ('Who did Beyonce donate the money to earned from her shows?',
#   'Clinton Bush Haiti Fund'),
#  ('Who did Beyoncé marry?', 'Jay Z.'),
#  (" I've never looked for the hidden images, but I imagine they are there! It's part of the playful nature of the company. It wants to create many layers of fun for the viewers.",
#   " Yes, and thus I'm not surprised they're so succesful. That's very creative and engaging, and keeps viewers interested and coming back... genius!"),
#  (' I have in the past. Kind of amazing someone built a working computer using only the mine craft building blocks.',
#   " Yeah, that is pretty crazy. I'm not even sure how that is possible? "),
#  ('Which film did Beyoncé star with Steve Martin in?', 'The Pink Panther'),
#  ("When did Destiny's Child end their group act?", 'June 2005'),
#  (' They have that?  Ok... im kinda jealous now.',
#   ' They do, seems like the best option at times lol'),
#  ('Who influenced Beyonce?', 'Michael Jackson'),
#  (' Oh absolutely! Really all art forms and most certainly the internet is going to bring humanity together on a much more even playing field. It was really nice talking with you!',
#   ' Hello! Are you an Amazon Prime member?'),
#  ('Where does she place in writing credits  for three number one songs?',
#   'third woman'),
#  ("Which artist was associated with Beyoncé's premiere solo recording?",
#   'Jay Z'),
#  (' Yes those sayings certainly seemed to have stuck into modern language',
#   ' Pocahontas and Shakespeare were alive at the same time and died only a year apart.  Interesting facts.'),
#  ("Who is Beyoncé's alter ego?", 'Sasha Fierce'),
#  (' Yes especially with punk and rhymes, they do not work with modern language',
#   " Yeah. Did you know Tchaikozsky donated his skull in hopes it will be used in Shakespeare's plays?"),
#  ('When did Beyoncé release Dangerously in Love?', '2003'),
#  ('Her first appearance performing since giving birth was where?',
#   "Revel Atlantic City's Ovation Hall"),
#  (' Cool word! Did you know there are 20 quintillion animal varieties on Earth?',
#   ' That is a lot! And in 2002 Germany gave them legal rights.'),
#  (" Not sure how true it is, but that's what I've been told. Did you know Hillary Clinton was president of young republicans in college?",
#   " I'm not surprised. Did you know Arnold traveled 3 hours a day to Sacramento when he was the governor? "),
#  (' Yeah apparently lol! They do that instead of hiring people to mow!',
#   ' thats both funny and i guess imaginative. leave it to a huge tech company to employ actual goats!'),
#  (" If I'm watching a movie at home I don't care about the reviews as much but definitely want to make sure I am getting my moneys worth at the theater.",
# ...
#   ' For sure. They should do it like athens did back in the day. Use a lottery system to prevent oligarchy! I think he is cheating the system'),
#  ("What song name does the band Suga Mama  and a song on the B'Day album share?",
#   'Suga Mama'),
#  ('What did Beyoncé win in 2001, making her the first black woman to do so?',
#   'Pop Songwriter of the Year award'),
#  (' Yes he even won a cha cha championship in 1958',
#   ' Yeah. Did you know ballet dancers use a lot of shoes?'),
#  ("Who managed the Destiny's Child group?", 'Mathew Knowles'),
#  (' it is like kids in korea being banned playing games after 12',
#   " after or before 12? If after 12, why is it so? I used to play a lot when I was child. I'm not surprised that video games make more money abbually than all films from Hollywood."),
#  (' Yes, they are.  In 2002, germany became the first country in the world to universally give animals constitutionally-guaranteed legal rights.',
#   ' I think that is a good thing!  I like how the netherlands is constructing wildlife bridges.'),
#  (' Me too. Julius Ceasar wrote fan fiction too!',
#   ' Wow.  Id like to see what came out of his mind!'),
#  (' Yes, I am and love it!  That two day delivery really comes in handy!!',
#   ' It really does! Even Sunday delivery rocks especially since Amazon contracted with the USPS.'),
#  (' Yes, sad indeed. Sharks even evolved earlier than dinosaurs and trees.',
#   " Have you ever seen the white shark cafe? It's where white sharks meet in the middle of the Pacific Ocean."),
#  (" That is crazy, but understandable.  And you are right, gives us no excuse.  Did you know about Jordan's political dealings?",
#   " I don't. Tell me more."),
#  ('Jay Z and Beyonce attended which event together in August of 2011?',
#   'MTV Video Music Awards'),
#  ('Beyonce has noted which first lady with saying "She proves you can do it all"?',
#   'Michelle Obama'),
#  (' Dogs are awesome, I think anyway, they have like 12 different blood types and apparently there are dog blood drives that exist',
#   ' I wonder how the dogs are rewarded at the drive. People get cookies and orange juice.'),
#  (' I agree.  I wonder why they gave themselves that moniker.  ',
#   " Yeah I'm not sure. But every US president with a beard has been Republican."),
#  (" That's great! I must be a wonderful film. It's a disney film, yes? Lots of songs?",
#   ' That is correct! produced by Walt Disney Animated Studios and released by Walt Disney Pictures. It was so cute! They also remade Rapunzel as Tangled, have you seen that?'),
#  (' Nice. Do you like soundtracks?',
#   ' Yes I do. Did you know Spielberg, when creating the soundtrack for Jaws, played the clarinet?'),
#  (' I agree with you. It was so nice chatting with you!',
#   " No. I think it's so interesting that the Republican Party is referred to as the Grand old party."),
#  ('When did Beyonce begin her second world tour?', 'March 2009'),
#  (' Yes and there are blood drives for dogs',
#   ' So cool. In istanbul they have installed water and food dispensers for dogs'),
#  ('Beyonce had an all-female tour band whose name was what?', 'Suga Mama'),
#  (" Big Sean is? Weird, most have never heard of him. I do like Kanye's middle name, Omari,. ",
#   " So his initials are K.O.W. That's funny! "),
#  ("Who is Beyoncé's biggest musical influence?", 'Michael Jackson'),
#  (" The Bush's had a heck of a run with three terms.  In fact, before Trump, you'd have to go back to 1928 to find an elected republican that didn't have nixon or a bush.",
#   ' Thats interesting,  do you know much about our planets?  The planet uranus rotates sideways instead of spinning. '),
#  ('Which singer did Beyoncé portray in Cadillac Records?', 'Etta James'),
#  (' I hear they go through four pairs of pointe shoes a week. Lots of wear.',
#   ' Soundtracks are important in dance, as well as movies, too.'),
#  (' Me either. Did you know the government of Oklahoma has an Oklahoma shaped pool?',
#   ' No, weird. Is a hew a professional swimmer? '),
#  (' Nice. Ballet dancers go through tons of shoes, 4 pairs a week',
#   ' Yeah must cost a lot too. Babies are good at dancing too when they hear music'),
#  (' Steven spielberg still makes millions from star wars off a bet with george lucas they made in 1977!',
#   ' haha thats awesome,  I wonder what the bet was.Steven spielberg played the clarinet in the jaws soundtrack. '),
#  (' Yeah, I heard about that. I feel horrible for her young daughter',
#   " Sorry, Ana Gloria Henrequez is the grandmother, my bad. Ximena is the girl and the mother is Cindy. They said that they never had been caught until Trump's laws."),
#  ('In her music, what are some recurring elements in them?',
#   'love, relationships, and monogamy'),
#  (' I was wondering the same! After filming the goonies steven spielberg flew the entire cast to hawaii and surprised director richard donner with a cookout.',
#   ' Amazing!  Thats so nice. When steven spielberg rode jurassic park the ride on opening day he requested that he was let off before the 84 foot drop'),
#  (" Same here. I don't follow local as I do not live in the same state more than 3 years at a time.",
#   " I see. Do you know who has a higher authority than a state's governor?"),
#  (' Same thing to you. Good day.', ' You have a good day too!'),
#  (' I think I read the cliff notes to one of his plays, but I could never stay interested in his works!',
#   ' I read the cliff notes of some of his things in college.  He coined a lot of popular phrases that we still use today like "good riddance" and "wild goose chase".'),
#  ("New York Times' Jon Pareles calls Beyoncé's voice velvety yet what?",
#   'tart'),
#  ('What song did Beyoncé perform at the first inaugural dance for the Obamas.',
#   'At Last'),
#  ('Which prominent star felt the 2009 Female Video of the Year award should have went to Beyoncé instead of Taylor Swift?',
#   'Kanye West'),
#  ('When did Beyoncé endorse on March 26, 2013?', 'same sex marriage'),
#  ('The letter Beyonce signed focused on what issue?', 'women'),
#  ('Their third album, Survivor, sold how many during its first week?',
#   '663,000 copies'),
#  (" Haha! I'm slightly certain that soon, they will write poetry. Computers have come such a long way! I found something really interesting, in 1936 the Russians made a computer that ran off of water! I wonder what went wrong with that. Maybe electricity and water wasn't the best idea?",
#   ' Computers can be fairly delicate, I suppose. Smoking near apply computers voids the warranty by making it "a biohazard". What in the world could that mean?'),
#  ("Beyonce's mother worked in what industry?", 'hairdresser and salon owner'),
#  ('Which song did Beyonce sing to win a competition at age 7?', 'Imagine'),
#  (' Never been to Oregon, but not a state I think I would want to live in with all of the rain they get. ',
#   " Yeah, I'm not a huge fan of rainy states to be honest. "),
#  ('The lead single from the album was which song?', 'Déjà Vu'),
#  (' I read that and thought the same. I wonder how similar the Zebra Fish is to humans? Can we use that in medical research?',
#   " If we can i'm sure it will be preventative or medication. There's no money in cures. I didn't realize that we had already cloned a cat and named it Copy Cat, that's too funny."),
#  ('In what year did Beyonce have her hiatus?', '2010'),
#  ('What movie influenced Beyonce towards empowerment themes? ', 'Dreamgirls'),
#  (' I bet it was pretty good, it was about Hercules and Oedipus, I wonder if he was good.',
#   " Game of Thrones author, George RR Martin, might not have cared for it.  Maybe Caesar would get a pass, but Martin doesn't care for fan fiction at all!"),
#  ('What was the name of the streaming service?', 'Tidal'),
#  (' Hobos? I never thought of income in terms of hobos, though I guess they do make money through their illicit means. ',
#   " Panhandling can be quite profitable, for someone with no income. Like in a busy place as Manhattan. But even if I don't consider softball as a legitimate pro sport, if was the first event televised on ESPN.   "),
#  (" Yah, it's quite a bit larger than a baseball for sure, I've never seen a softball video game though, have you?",
#   " No I've never seen one actually. It's interesting though that the average salary for a professional softball player is at most $6,000 LOL definitely you're not retiring on that money"),
#  (" Have you ever used the Rotten Tomatoes website? I check out all the movies I'm going to watch on there first.",
#   " You know, I do to.  I feel it's better to be informed than waste my time or money without knowing."),
#  ('Beyonce does not create which aspect of her music?', 'beats'),
#  (" Oh I'm Sure. Do you like dogs by the way? We used to have a husky ourselves",
#   ' A dog is a great friend, but no, I have never had a dog. I enjoy playing with them though.'),
#  ('How many nominations did Beyoncé receive at the 52nd Grammy Awards ceremony?',
#   'ten'),
#  ('How old was Beyonce when she went to her first Michael Jackson concert as a kid?',
#   'five'),
#  (' That is so fascinating, I love his works of fiction. I like fiction because it is so imaginative. What is your favorite genre?',
#   ' I like non fiction because i want to keep up with what is going on in the world. '),
#  (" That is crazy! I also think it's crazy that there is a jellyfish breed that can never die AKA its immortal",
#   " Does that mean they never get cancer, or they get cancer forever? You know, 84% of genes associated with human disease are also found in the zebrafish, but I have never seen a zebrafish with MS or Parkinson's disease..."),
#  ('Where did Beyoncé announce her pregnancy?', '2011 MTV Video Music Awards'),
#  ('What part of production does she do?', 'melodies'),
#  (' Yeah. Google is a dog company it seems',
#   ' Yes they have that in their code of conduct, talk about dedication'),
#  ("In what year did Beyonce's father quit his job to manage her group?",
#   '1995'),
#  ('Which critic called Beyonce\'s voice "versatile"?', 'The Daily Mail'),
#  ('How many digital copies of her fifth album did Beyoncé sell in six days?',
#   'one million'),
#  (" I wonder if that person even shows up to vote, or why he's in the jungle like that haha. Did you vote last election?",
#   " Yes I did. And even though we don't have to go to a forest full of lions, voter turnout for US presidential elections has not reached 62.8 percent in the last 100 years."),
#  (' That would freak me out! But I bet it catches that prey using its acoustic communication!',
#   " Could be. Fish are cool like that. I think it's neat that amphibians and reptiles and birds and mammals all had the same ancestry with fish."),
#  (' I actually enjoy watching college softball on ESPNU!',
#   ' Really? the womens game? do men play as well?'),
#  ('Which song by Jay Z talked about the pregnancy struggles?', 'Glory'),
#  ('How many copies did the album sell in its first week?', '310,000 copies'),
#  (' Yes they go through 4 pairs in a single week',
#   ' Yeah that is a lot of shoes and also a lot of money'),
#  (' And there are more pets in Japan than there are children under 15. You can\'t be a pets "OWNER" in Boulder but you can be their guardian.  ',
#   ' I have a pet. I am an ailurophile meaning I love cats.'),
#  (' Yeah!! That is correct. He was a fantastic martial artist. Did you know that Tupac danced ballet in high school?',
#   ' Yeah!  He was the mouse king in the Nutcracker.  Thats pretty cool, I would definitely never have guessed that about him.'),
#  (' Oooo imagine the animals in the unexplored water world we have not seen yet. 4.5 million years old and the world has animals in its oceans for quite some time now. Like the lizards. ',
#   ' when the earth was first formed a day was only 5.5 hours long. It was nice chatting with you, have a good night.'),
#  (' Unfortunately yes.  It is not like the republican party of old times.',
#   ' Yeah a lot of things have changed, funny anecdote with Truman and Dumbo though'),
#  (' Yeah you probably did. I love the hobbit too. Most of the character names were taken out of an old Icelandic poem called dvergatal.',
#   ' Yes, Tolkien loved old languages. he studied them and learned to speak some of them. '),
#  ('What was the name of the woman she played in Obsessed?', 'Sharon Charles'),
#  (" Haha that's a lot of animals! We have a dog actually, but I can't believe that there are more pet tigers in the USA than Wild Ones in Asia, a lot of people must have illegal pets here",
#   ' Can you recommend any movies to watch?'),
#  (' Yeah. DO you like SHakespeare?',
#   ' I love his work. Did you know he popularized many terms that we use to this day?'),
#  (' Right me neither, there were so many good choices of comics when I was growing up. ',
#   ' Not where I lived, if I want to read a comic book, I had to go to the library. But as I think about it Tintin is a comic book, so I was wrong, I did read a lot of them when I was young but they were European.  '),
#  (" Yeah, no insurance company would touch the managers on the field, that's for sure.",
#   ' I think they would be better at softball, did you ever watch a softball game ? '),
#  ("What large record company recorded Beyonce's group's first album?",
#   'Sony Music'),
#  ('How many weeks did their single "Independent Women Part I" stay on top?',
#   'eleven'),
#  ("What was Beyoncé's first acting job, in 2006?", 'Dreamgirls'),
#  (" I did, I voted Hillary even though I didn't really care for her either, but she was a much better choice than what we ended up with.",
#   ' For sure, I voted third party. I was part of the problem, I wanted a 3rd party to win because it has been years!'),
#  ('With what British band did Beyonce perform on their album?', 'Coldplay'),
#  ('Which magazine declared her the most dominant woman musician?', 'Forbes'),
#  (' It\'s funny that it\'s protected by 1912 Scottish law, the "protection of animals act". hopefully that means that it\'s a real animal LOL but I doubt it',
#   ' Yeah. Aunt Matilda would make a better hag fish anyway, or maybe a seahorse, since they are the only fish with a neck. '),
#  (' I used to play video games. Not much now. Lost interest. Do you? ',
#   ' Me too, I have lost interest playing before I have lost interest in buy them so I have a backlog of a few games that reminds me  not to buy the next console. It is the more and more popular, 3 billon hours are played on video games each week on Earth. '),
#  ('Beyonce gave a tribute award to who in 2006?', 'Michael Jackson'),
#  ('To whom was the letter addressed?',
#   'Angela Merkel and Nkosazana Dlamini-Zuma'),
#  (' Sorry, what I meant was "she won the award". About James Earl Jones - I think he was only paid $7500 for his work.  That was not fair.',
#   " Wow.  That sure doesn't.  I wonder if he gets any licensing fees at all for Darth Vader?  On a different subject....did you know that Earth's surface is 71 percent water and 29 percent land?"),
#  (" In 1934 I see that North Dakota's governor declared martial law and seceded from the US.  I'm learning all kinds of new things today.",
#   ' Wow! Well, Texas elected their first female Governor, the second in the nation, before some states even ratified the 19th amendment. '),
#  (' Yes indeed, interesting facts that will give me pause this weekend. That was an enjoyable conversation. Thanks and have a lovely weekend.',
#   ' You as well!!'),
#  ('Who is Beyoncé married to?', 'Jay Z'),
#  ("What song on Beyoncé's fifth studio album featured her husband?",
#   'Drunk in Love'),
#  (" Larry Hogan could probably have used the support of a group like the Beatles, but I'm sure he will be ok.  At least he isn't as bad as North Dakota's in 1934 who actually seceded from the US for a short time!",
#   ' when schwarzenegger became governor of ca he commuted 3 hours everyday lol '),
#  ('Which magazine did Beyoncé pose for the cover, making her the first black female artist to do so?',
#   'Vogue'),
#  (' Some, I know Schwarzenegger never lived in Sacramento, he commuted daily by private jet.',
#   ' That would be hard to do. It says he went 3 hours per day by private jet. Talk about a long commute.'),
#  ...]

# %%
import numpy as np
import re

input_docs = []
target_docs = []
input_tokens = set()
target_tokens = set()

for line in pairs[:1200]:
  input_doc, target_doc = line[0], line[1]

  input_doc = clean_text(input_doc)
  target_doc = clean_text(target_doc)

  # Appending each input sentence to input_docs
  input_docs.append(input_doc)
  
  # Splitting words from punctuation  
  target_doc = " ".join(re.findall(r"[\w']+|[^\s\w]", target_doc))

  # Redefine target_doc below and append it to target_docs
  target_doc = '<START> ' + target_doc + ' <END>'
  target_docs.append(target_doc)

  
  # Now we split up each sentence into words and add each unique word to our vocabulary set
  for token in re.findall(r"[\w']+|[^\s\w]", input_doc):
    if token not in input_tokens:
      input_tokens.add(token)
       
  for token in target_doc.split():
    if token not in target_tokens:
      target_tokens.add(token)


input_tokens = sorted(list(input_tokens))
target_tokens = sorted(list(target_tokens))
num_encoder_tokens = len(input_tokens)
num_decoder_tokens = len(target_tokens)

# target_tokens

# %%
print(input_tokens)
# Out:
# ['-', '001', '1', '10', '100', '10000', '11', '1110', '12', '15', '15000000', '16', '165', '17', '1853', '1895', '19', '1900', '1909', '1912', '1918', '1928', '1934', '1936', '1940', '1950s', '1958', '1963', '1977', '1980', '1991', '1992', '1993', '1994', '1995', '1998', '19th', '1mb', '2', '20', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2020', '20th', '224', '24', '2430', '26', '270', '2795', '29', '2nd', '3', '3000', '309', '30s', '31', '32000', '38', '39', '3rd', '4', '40', '4000', '4040', '43', '45', '4500', '46th', '49', '4th', '5', '50', '500k', '52nd', '55', '57th', '5th', '6', '622', '628', '63', '6331', '64', '7', '70k', '71', '75', '7500', '8', '80', '84', '85', '9', 'a', 'abc', 'abilities', 'ability', 'able', 'about', 'above', 'absentee', 'absolutely', 'acadian', 'accent', 'accept', 'acclaim', 'according', 'achieve', 'achieved', 'acoustic', 'acquittal', 'act', 'acting', 'active', 'activity', 'actor', 'actual', 'actually', 'adam', 'adams', 'added', 'addition', 'additional', 'addressed', 'adopting', 'adore', 'adult', 'advanced', 'adventure', 'aesthetic', 'affect', 'african', 'after', 'afternoon', 'again', 'against', 'age', 'agnostics', 'ago', 'agree', 'agreed', 'ah', 'ahead', 'aherents', 'aids', 'aimed', 'air', 'aka', 'alaska', 'album', 'albums', 'ali', 'aliens', 'alive', 'all', 'allan', 'allen', 'allergic', 'allergies', 'allow', 'allowed', 'almost', 'along', 'alphabet', 'already', 'also', 'alter', 'although', 'always', 'am', 'amazing', 'amazingly', 'amazon', 'amazoncom', 'amendment', 'america', 'american', 'amicable', 'among', 'amount', 'amounts', 'amsasha', 'amusement', 'amy', 'an', 'anatomy', 'ancient', 'and', 'andersen', 'anderson', 'angela', 'angels', 'angry', 'animal', 'animals', 'animated', 'animation', 'announce', 'announced', 'announcing', 'annual', 'another', 'antarctic', 'anthem', 'any', 'anyone', 'anything', 'anyway', 'anyways', 'apart', 'apparel', 'apparently', 'appear', 'appearance', 'appeared', 'appears', 'apple', 'appointed', 'appointment', 'approval', 'april', 'arcadian', 'arctic', 'are', 'areas', 'aristotle', 'arithmetic', 'arm', 'around', 'arrested', 'art', 'artist', 'artists', 'as', 'asia', 'asked', 'askew', 'aspect', 'aspiring', 'associated', 'association', 'asteroids', 'astronaut', 'astronauts', 'at', 'atari', 'athens', 'athletes', 'athleticism', 'atlantic', 'attack', 'attacks', 'attempt', 'attend', 'attended', 'attention', 'attic', 'audience', 'audiobooks', 'aug', 'august', 'austin', 'author', 'authors', 'available', 'average', 'avoid', 'avoided', 'award', 'awarded', 'awards', 'away', 'awesome', 'awful', 'awhile', 'axl', 'b', 'babel', 'babies', 'baby', 'back', 'background', 'backup', 'backwards', 'bad', 'bag', 'bail', 'baker', 'ball', 'ballet', 'ballot', 'ballots', 'ballroom', 'balls', 'ban', 'band', 'banned', 'bark', 'barrier', 'bars', 'baseball', 'based', 'basically', 'basics', 'basquiat', 'bat', 'battle', 'battles', 'bay', 'bc', 'be', 'beanies', 'beans', 'bear', 'beard', 'bearded', 'beards', 'beat', 'beatles', 'beats', 'beautiful', 'beauty', 'became', 'because', 'become', 'becoming', 'bed', 'been', 'before', 'began', 'begin', 'behave', 'behavior', 'behind', 'being', 'believe', 'believed', 'benefit', 'benefits', 'bernie', 'besides', 'best', 'bet', 'better', 'betting', 'between', 'bexos', 'beyonce', 'beyoncé', 'bezos', 'bible', 'bic', 'biden', 'big', 'bigger', 'biggest', 'bill', 'billboard', 'billion', 'bimbo', 'bio', 'birth', 'birthday', 'bit', 'black', 'blade', 'blamed', 'blinker', 'blocked', 'blocks', 'blood', 'blown', 'blue', 'board', 'body', 'booing', 'book', 'booked', 'books', 'bookshelf', 'boost', 'booth', 'border', 'boring', 'born', 'bossy', 'both', 'bottles', 'bottom', 'boulder', 'bound', 'bowl', 'bowler', 'box', 'boys', 'bozo', 'brain', 'brains', 'brand', 'breached', 'break', 'breakfast', 'breed', 'breeds', 'brett', 'brilliant', 'bring', 'bringing', 'british', 'broadcast', 'bros', 'brother', 'brough ...

# %%
input_features_dict = dict(
    [(token, i) for i, token in enumerate(input_tokens)])
target_features_dict = dict(
    [(token, i) for i, token in enumerate(target_tokens)])

reverse_input_features_dict = dict(
    (i, token) for token, i in input_features_dict.items())
reverse_target_features_dict = dict(
    (i, token) for token, i in target_features_dict.items())

# %%
max_encoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", input_doc)) for input_doc in input_docs])
max_decoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", target_doc)) for target_doc in target_docs])

encoder_input_data = np.zeros(
    (len(input_docs), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

for line, (input_doc, target_doc) in enumerate(zip(input_docs, target_docs)):
    for timestep, token in enumerate(re.findall(r"[\w']+|[^\s\w]", input_doc)):
        #Assign 1. for the current line, timestep, & word in encoder_input_data
        encoder_input_data[line, timestep, input_features_dict[token]] = 1.
    
    for timestep, token in enumerate(target_doc.split()):
        decoder_input_data[line, timestep, target_features_dict[token]] = 1.
        if timestep > 0:
            decoder_target_data[line, timestep - 1, target_features_dict[token]] = 1.

# %%
max_encoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", input_doc)) for input_doc in input_docs])
max_decoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", target_doc)) for target_doc in target_docs])

encoder_input_data = np.zeros(
    (len(input_docs), max_encoder_seq_length), dtype='int32'
)
decoder_input_data = np.zeros(
    (len(input_docs), max_decoder_seq_length), dtype='int32'
)
decoder_output_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='int32'
  )
for line, (input_doc, target_doc) in enumerate(zip(input_docs, target_docs)):
  for timestep, token in enumerate(re.findall(r"[\w']+|[^\s\w]", input_doc)):
    encoder_input_data[line, timestep] = input_features_dict[token]
  for timestep, token in enumerate(target_doc.split()):
    decoder_input_data[line, timestep] = target_features_dict[token]
    if timestep > 0:
        decoder_output_data[line, timestep - 1, target_features_dict[token]] = 1.

# %%
from tensorflow.keras import layers , activations , models , preprocessing

# %%
import tensorflow as tf

encoder_inputs = tf.keras.layers.Input(shape=( max_encoder_seq_length, ))
encoder_embedding = tf.keras.layers.Embedding( num_encoder_tokens, 200 , mask_zero=True) (encoder_inputs)
encoder_outputs , state_h , state_c = tf.keras.layers.LSTM( 200 , return_state=True )( encoder_embedding )
encoder_states = [ state_h , state_c ]

decoder_inputs = tf.keras.layers.Input(shape=( None ,  ))
decoder_embedding = tf.keras.layers.Embedding( num_decoder_tokens, 200 , mask_zero=True) (decoder_inputs)
decoder_lstm = tf.keras.layers.LSTM( 200 , return_state=True , return_sequences=True )
decoder_outputs , _ , _ = decoder_lstm ( decoder_embedding , initial_state=encoder_states )
decoder_dense = tf.keras.layers.Dense( num_decoder_tokens , activation=tf.keras.activations.softmax ) 
output = decoder_dense ( decoder_outputs )

model = tf.keras.models.Model([encoder_inputs, decoder_inputs], output )
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy')

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 62)]         0           []
#
#  input_4 (InputLayer)           [(None, None)]       0           []
#
#  embedding_2 (Embedding)        (None, 62, 200)      578800      ['input_3[0][0]']
#
#  embedding_3 (Embedding)        (None, None, 200)    530400      ['input_4[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 200),        320800      ['embedding_2[0][0]']
#                                  (None, 200),
#                                  (None, 200)]
#
#  lstm_3 (LSTM)                  [(None, None, 200),  320800      ['embedding_3[0][0]',
#                                  (None, 200),                     'lstm_2[0][1]',
#                                  (None, 200)]                     'lstm_2[0][2]']
#
#  dense (Dense)                  (None, None, 2652)   533052      ['lstm_3[0][0]']
#
# ==================================================================================================
# Total params: 2,283,852
# Trainable params: 2,283,852
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit([encoder_input_data , decoder_input_data], decoder_output_data, batch_size=50, epochs=200 ) 
model.save( 'model.h5' )
# Out:
# Epoch 1/200
# 24/24 [==============================] - 23s 486ms/step - loss: 6.6958
# Epoch 2/200
# 24/24 [==============================] - 10s 417ms/step - loss: 5.7706
# Epoch 3/200
# 24/24 [==============================] - 8s 342ms/step - loss: 5.6465
# Epoch 4/200
# 24/24 [==============================] - 9s 359ms/step - loss: 5.5741
# Epoch 5/200
# 24/24 [==============================] - 5s 217ms/step - loss: 5.5002
# Epoch 6/200
# 24/24 [==============================] - 9s 371ms/step - loss: 5.4047
# Epoch 7/200
# 24/24 [==============================] - 6s 251ms/step - loss: 5.3258
# Epoch 8/200
# 24/24 [==============================] - 6s 266ms/step - loss: 5.2552
# Epoch 9/200
# 24/24 [==============================] - 5s 190ms/step - loss: 5.1904
# Epoch 10/200
# 24/24 [==============================] - 6s 237ms/step - loss: 5.0912
# Epoch 11/200
# 24/24 [==============================] - 5s 225ms/step - loss: 5.0242
# Epoch 12/200
# 24/24 [==============================] - 5s 193ms/step - loss: 4.9334
# Epoch 13/200
# 24/24 [==============================] - 5s 219ms/step - loss: 4.8550
# Epoch 14/200
# 24/24 [==============================] - 4s 155ms/step - loss: 4.7728
# Epoch 15/200
# 24/24 [==============================] - 5s 197ms/step - loss: 4.6809
# Epoch 16/200
# 24/24 [==============================] - 6s 239ms/step - loss: 4.6141
# Epoch 17/200
# 24/24 [==============================] - 3s 145ms/step - loss: 4.5436
# Epoch 18/200
# 24/24 [==============================] - 4s 160ms/step - loss: 4.4593
# Epoch 19/200
# 24/24 [==============================] - 5s 207ms/step - loss: 4.4013
# Epoch 20/200
# 24/24 [==============================] - 4s 154ms/step - loss: 4.3328
# Epoch 21/200
# 24/24 [==============================] - 4s 172ms/step - loss: 4.2668
# Epoch 22/200
# 24/24 [==============================] - 5s 192ms/step - loss: 4.1996
# Epoch 23/200
# 24/24 [==============================] - 4s 172ms/step - loss: 4.1430
# Epoch 24/200
# 24/24 [==============================] - 4s 158ms/step - loss: 4.0809
# Epoch 25/200
# 24/24 [==============================] - 4s 165ms/step - loss: 4.0299
# Epoch 26/200
# 24/24 [==============================] - 5s 199ms/step - loss: 3.9666
# Epoch 27/200
# 24/24 [==============================] - 4s 153ms/step - loss: 3.9085
# Epoch 28/200
# 24/24 [==============================] - 3s 140ms/step - loss: 3.8591
# Epoch 29/200
# 24/24 [==============================] - 6s 230ms/step - loss: 3.7947
# Epoch 30/200
# 24/24 [==============================] - 4s 169ms/step - loss: 3.7409
# Epoch 31/200
# 24/24 [==============================] - 3s 145ms/step - loss: 3.6875
# Epoch 32/200
# 24/24 [==============================] - 5s 217ms/step - loss: 3.6372
# Epoch 33/200
# 24/24 [==============================] - 3s 139ms/step - loss: 3.5867
# Epoch 34/200
# 24/24 [==============================] - 4s 167ms/step - loss: 3.5436
# Epoch 35/200
# 24/24 [==============================] - 5s 200ms/step - loss: 3.4843
# Epoch 36/200
# 24/24 [==============================] - 4s 158ms/step - loss: 3.4421
# Epoch 37/200
# 24/24 [==============================] - 4s 147ms/step - loss: 3.3881
# Epoch 38/200
# 24/24 [==============================] - 3s 139ms/step - loss: 3.3355
# Epoch 39/200
# 24/24 [==============================] - 5s 218ms/step - loss: 3.2920
# Epoch 40/200
# 24/24 [==============================] - 4s 161ms/step - loss: 3.2476
# Epoch 41/200
# 24/24 [==============================] - 3s 132ms/step - loss: 3.2063
# Epoch 42/200
# 24/24 [==============================] - 4s 176ms/step - loss: 3.1610
# Epoch 43/200
# 24/24 [==============================] - 4s 166ms/step - loss: 3.1130
# Epoch 44/200
# 24/24 [==============================] - 4s 146ms/step - loss: 3.0629
# Epoch 45/200
# 24/24 [==============================] - 4s 170ms/step - loss: 3.0210
# Epoch 46/200
# 24/24 [==============================] - 5s 192ms/step - loss: 2.9740
# Epoch 47/200
# 24/24 [==============================] - 4s 156ms/step - loss: 2.9316
# Epoch 48/200
# 24/24 [==============================] - 3s 144ms/step - loss: 2.8834
# Epoch 49/200
# 24/24 [==============================] - 5s 200ms/step - loss: 2.8417
# Epoch 50/200
# 24/24 [==============================] - 3s 142ms/step - loss: 2.7918
# Epoch 51/200
# 24/24 [==============================] - 3s 132ms/step - loss: 2.7513
# Epoch 52/200
# 24/24 [==============================] - 4s 164ms/step - loss: 2.7121
# Epoch 53/200
# 24/24 [==============================] - 4s 183ms/step - loss: 2.6632
# Epoch 54/200
# 24/24 [==============================] - 3s 134ms/step - loss: 2.6209
# Epoch 55/200
# 24/24 [==============================] - 3s 143ms/step - loss: 2.5806
# Epoch 56/200
# 24/24 [==============================] - 5s 208ms/step - loss: 2.5348
# Epoch 57/200
# 24/24 [==============================] - 3s 146ms/step - loss: 2.5013
# Epoch 58/200
# 24/24 [==============================] - 3s 143ms/step - loss: 2.4551
# Epoch 59/200
# 24/24 [==============================] - 4s 153ms/step - loss: 2.4160
# Epoch 60/200
# 24/24 [==============================] - 4s 179ms/step - loss: 2.3805
# Epoch 61/200
# 24/24 [==============================] - 3s 148ms/step - loss: 2.3346
# Epoch 62/200
# 24/24 [==============================] - 4s 145ms/step - loss: 2.2986
# Epoch 63/200
# 24/24 [==============================] - 5s 203ms/step - loss: 2.2618
# Epoch 64/200
# 24/24 [==============================] - 4s 154ms/step - loss: 2.2234
# Epoch 65/200
# 24/24 [==============================] - 3s 144ms/step - loss: 2.1769
# Epoch 66/200
# 24/24 [==============================] - 3s 140ms/step - loss: 2.1499
# Epoch 67/200
# 24/24 [==============================] - 5s 185ms/step - loss: 2.1151
# Epoch 68/200
# 24/24 [==============================] - 4s 142ms/step - loss: 2.0660
# Epoch 69/200
# 24/24 [==============================] - 4s 150ms/step - loss: 2.0479
# Epoch 70/200
# 24/24 [==============================] - 5s 205ms/step - loss: 2.0067
# Epoch 71/200
# 24/24 [==============================] - 4s 148ms/step - loss: 1.9696
# Epoch 72/200
# 24/24 [==============================] - 3s 127ms/step - loss: 1.9422
# Epoch 73/200
# 24/24 [==============================] - 3s 141ms/step - loss: 1.9117
# Epoch 74/200
# 24/24 [==============================] - 4s 184ms/step - loss: 1.8812
# Epoch 75/200
# 24/24 [==============================] - 3s 150ms/step - loss: 1.8466
# Epoch 76/200
# 24/24 [==============================] - 3s 136ms/step - loss: 1.8157
# Epoch 77/200
# 24/24 [==============================] - 4s 159ms/step - loss: 1.7842
# Epoch 78/200
# 24/24 [==============================] - 4s 173ms/step - loss: 1.7512
# Epoch 79/200
# 24/24 [==============================] - 4s 146ms/step - loss: 1.7225
# Epoch 80/200
# 24/24 [==============================] - 3s 146ms/step - loss: 1.6940
# Epoch 81/200
# 24/24 [==============================] - 5s 192ms/step - loss: 1.6667
# Epoch 82/200
# 24/24 [==============================] - 3s 142ms/step - loss: 1.6304
# Epoch 83/200
# 24/24 [==============================] - 4s 149ms/step - loss: 1.6035
# Epoch 84/200
# 24/24 [==============================] - 4s 150ms/step - loss: 1.5787
# Epoch 85/200
# 24/24 [==============================] - 4s 175ms/step - loss: 1.5492
# Epoch 86/200
# 24/24 [==============================] - 3s 145ms/step - loss: 1.5202
# Epoch 87/200
# 24/24 [==============================] - 3s 145ms/step - loss: 1.4975
# Epoch 88/200
# 24/24 [==============================] - 5s 203ms/step - loss: 1.4660
# Epoch 89/200
# 24/24 [==============================] - 3s 144ms/step - loss: 1.4443
# Epoch 90/200
# 24/24 [==============================] - 3s 140ms/step - loss: 1.4161
# Epoch 91/200
# 24/24 [==============================] - 4s 157ms/step - loss: 1.3925
# Epoch 92/200
# 24/24 [==============================] - 4s 178ms/step - loss: 1.3708
# Epoch 93/200
# 24/24 [==============================] - 3s 139ms/step - loss: 1.3549
# Epoch 94/200
# 24/24 [==============================] - 3s 139ms/step - loss: 1.3282
# Epoch 95/200
# 24/24 [==============================] - 5s 191ms/step - loss: 1.3016
# Epoch 96/200
# 24/24 [==============================] - 4s 142ms/step - loss: 1.2831
# Epoch 97/200
# 24/24 [==============================] - 3s 137ms/step - loss: 1.2568
# Epoch 98/200
# 24/24 [==============================] - 3s 142ms/step - loss: 1.2345
# Epoch 99/200
# 24/24 [==============================] - 5s 201ms/step - loss: 1.2104
# Epoch 100/200
# 24/24 [==============================] - 4s 146ms/step - loss: 1.1831
# Epoch 101/200
# 24/24 [==============================] - 3s 141ms/step - loss: 1.1660
# Epoch 102/200
# 24/24 [==============================] - 4s 185ms/step - loss: 1.1451
# Epoch 103/200
# 24/24 [==============================] - 4s 153ms/step - loss: 1.1251
# Epoch 104/200
# 24/24 [==============================] - 4s 149ms/step - loss: 1.1056
# Epoch 105/200
# 24/24 [==============================] - 4s 150ms/step - loss: 1.0835
# Epoch 106/200
# 24/24 [==============================] - 5s 198ms/step - loss: 1.0615
# Epoch 107/200
# 24/24 [==============================] - 3s 145ms/step - loss: 1.0410
# Epoch 108/200
# 24/24 [==============================] - 3s 141ms/step - loss: 1.0215
# Epoch 109/200
# 24/24 [==============================] - 4s 180ms/step - loss: 1.0001
# Epoch 110/200
# 24/24 [==============================] - 4s 163ms/step - loss: 0.9813
# Epoch 111/200
# 24/24 [==============================] - 3s 138ms/step - loss: 0.9644
# Epoch 112/200
# 24/24 [==============================] - 3s 131ms/step - loss: 0.9505
# Epoch 113/200
# 24/24 [==============================] - 5s 193ms/step - loss: 0.9311
# Epoch 114/200
# 24/24 [==============================] - 3s 136ms/step - loss: 0.9116
# Epoch 115/200
# 24/24 [==============================] - 3s 142ms/step - loss: 0.8969
# Epoch 116/200
# 24/24 [==============================] - 4s 163ms/step - loss: 0.8791
# Epoch 117/200
# 24/24 [==============================] - 4s 177ms/step - loss: 0.8601
# Epoch 118/200
# 24/24 [==============================] - 3s 145ms/step - loss: 0.8478
# Epoch 119/200
# 24/24 [==============================] - 4s 148ms/step - loss: 0.8283
# Epoch 120/200
# 24/24 [==============================] - 5s 197ms/step - loss: 0.8116
# Epoch 121/200
# 24/24 [==============================] - 4s 151ms/step - loss: 0.7955
# Epoch 122/200
# 24/24 [==============================] - 3s 117ms/step - loss: 0.7753
# Epoch 123/200
# 24/24 [==============================] - 3s 146ms/step - loss: 0.7661
# Epoch 124/200
# 24/24 [==============================] - 4s 185ms/step - loss: 0.7514
# Epoch 125/200
# 24/24 [==============================] - 3s 127ms/step - loss: 0.7320
# Epoch 126/200
# 24/24 [==============================] - 3s 122ms/step - loss: 0.7228
# Epoch 127/200
# 24/24 [==============================] - 4s 154ms/step - loss: 0.7063
# Epoch 128/200
# 24/24 [==============================] - 4s 185ms/step - loss: 0.6992
# Epoch 129/200
# 24/24 [==============================] - 3s 137ms/step - loss: 0.6861
# Epoch 130/200
# 24/24 [==============================] - 3s 136ms/step - loss: 0.6704
# Epoch 131/200
# 24/24 [==============================] - 4s 170ms/step - loss: 0.6578
# Epoch 132/200
# 24/24 [==============================] - 4s 164ms/step - loss: 0.6398
# Epoch 133/200
# 24/24 [==============================] - 3s 141ms/step - loss: 0.6282
# Epoch 134/200
# 24/24 [==============================] - 3s 129ms/step - loss: 0.6125
# Epoch 135/200
# 24/24 [==============================] - 5s 199ms/step - loss: 0.5976
# Epoch 136/200
# 24/24 [==============================] - 3s 143ms/step - loss: 0.5908
# Epoch 137/200
# 24/24 [==============================] - 3s 143ms/step - loss: 0.5763
# Epoch 138/200
# 24/24 [==============================] - 4s 164ms/step - loss: 0.5617
# Epoch 139/200
# 24/24 [==============================] - 4s 170ms/step - loss: 0.5482
# Epoch 140/200
# 24/24 [==============================] - 3s 131ms/step - loss: 0.5362
# Epoch 141/200
# 24/24 [==============================] - 4s 151ms/step - loss: 0.5236
# Epoch 142/200
# 24/24 [==============================] - 5s 189ms/step - loss: 0.5157
# Epoch 143/200
# 24/24 [==============================] - 4s 155ms/step - loss: 0.5050
# Epoch 144/200
# 24/24 [==============================] - 3s 145ms/step - loss: 0.4929
# Epoch 145/200
# 24/24 [==============================] - 4s 185ms/step - loss: 0.4796
# Epoch 146/200
# 24/24 [==============================] - 4s 162ms/step - loss: 0.4732
# Epoch 147/200
# 24/24 [==============================] - 4s 153ms/step - loss: 0.4640
# Epoch 148/200
# 24/24 [==============================] - 3s 131ms/step - loss: 0.4552
# Epoch 149/200
# 24/24 [==============================] - 5s 207ms/step - loss: 0.4459
# Epoch 150/200
# 24/24 [==============================] - 3s 142ms/step - loss: 0.4352
# Epoch 151/200
# 24/24 [==============================] - 3s 142ms/step - loss: 0.4252
# Epoch 152/200
# 24/24 [==============================] - 3s 144ms/step - loss: 0.4167
# Epoch 153/200
# 24/24 [==============================] - 5s 196ms/step - loss: 0.4071
# Epoch 154/200
# 24/24 [==============================] - 3s 136ms/step - loss: 0.4011
# Epoch 155/200
# 24/24 [==============================] - 3s 137ms/step - loss: 0.3892
# Epoch 156/200
# 24/24 [==============================] - 4s 168ms/step - loss: 0.3841
# Epoch 157/200
# 24/24 [==============================] - 4s 151ms/step - loss: 0.3756
# Epoch 158/200
# 24/24 [==============================] - 3s 128ms/step - loss: 0.3668
# Epoch 159/200
# 24/24 [==============================] - 4s 154ms/step - loss: 0.3554
# Epoch 160/200
# 24/24 [==============================] - 5s 199ms/step - loss: 0.3469
# Epoch 161/200
# 24/24 [==============================] - 3s 141ms/step - loss: 0.3376
# Epoch 162/200
# 24/24 [==============================] - 4s 148ms/step - loss: 0.3285
# Epoch 163/200
# 24/24 [==============================] - 4s 167ms/step - loss: 0.3199
# Epoch 164/200
# 24/24 [==============================] - 4s 157ms/step - loss: 0.3123
# Epoch 165/200
# 24/24 [==============================] - 3s 139ms/step - loss: 0.3060
# Epoch 166/200
# 24/24 [==============================] - 3s 141ms/step - loss: 0.2985
# Epoch 167/200
# 24/24 [==============================] - 5s 201ms/step - loss: 0.2914
# Epoch 168/200
# 24/24 [==============================] - 3s 137ms/step - loss: 0.2845
# Epoch 169/200
# 24/24 [==============================] - 3s 136ms/step - loss: 0.2784
# Epoch 170/200
# 24/24 [==============================] - 3s 127ms/step - loss: 0.2730
# Epoch 171/200
# 24/24 [==============================] - 5s 194ms/step - loss: 0.2668
# Epoch 172/200
# 24/24 [==============================] - 4s 161ms/step - loss: 0.2614
# Epoch 173/200
# 24/24 [==============================] - 3s 139ms/step - loss: 0.2564
# Epoch 174/200
# 24/24 [==============================] - 4s 182ms/step - loss: 0.2491
# Epoch 175/200
# 24/24 [==============================] - 4s 164ms/step - loss: 0.2418
# Epoch 176/200
# 24/24 [==============================] - 4s 145ms/step - loss: 0.2370
# Epoch 177/200
# 24/24 [==============================] - 3s 150ms/step - loss: 0.2341
# Epoch 178/200
# 24/24 [==============================] - 5s 203ms/step - loss: 0.2312
# Epoch 179/200
# 24/24 [==============================] - 3s 136ms/step - loss: 0.2240
# Epoch 180/200
# 24/24 [==============================] - 3s 140ms/step - loss: 0.2192
# Epoch 181/200
# 24/24 [==============================] - 4s 180ms/step - loss: 0.2126
# Epoch 182/200
# 24/24 [==============================] - 4s 149ms/step - loss: 0.2077
# Epoch 183/200
# 24/24 [==============================] - 3s 124ms/step - loss: 0.1997
# Epoch 184/200
# 24/24 [==============================] - 3s 137ms/step - loss: 0.1940
# Epoch 185/200
# 24/24 [==============================] - 4s 175ms/step - loss: 0.1878
# Epoch 186/200
# 24/24 [==============================] - 4s 144ms/step - loss: 0.1827
# Epoch 187/200
# 24/24 [==============================] - 4s 153ms/step - loss: 0.1768
# Epoch 188/200
# 24/24 [==============================] - 4s 147ms/step - loss: 0.1703
# Epoch 189/200
# 24/24 [==============================] - 5s 192ms/step - loss: 0.1667
# Epoch 190/200
# 24/24 [==============================] - 3s 137ms/step - loss: 0.1627
# Epoch 191/200
# 24/24 [==============================] - 3s 140ms/step - loss: 0.1602
# Epoch 192/200
# 24/24 [==============================] - 4s 182ms/step - loss: 0.1575
# Epoch 193/200
# 24/24 [==============================] - 4s 172ms/step - loss: 0.1552
# Epoch 194/200
# 24/24 [==============================] - 3s 139ms/step - loss: 0.1540
# Epoch 195/200
# 24/24 [==============================] - 3s 139ms/step - loss: 0.1507
# Epoch 196/200
# 24/24 [==============================] - 5s 190ms/step - loss: 0.1462
# Epoch 197/200
# 24/24 [==============================] - 3s 127ms/step - loss: 0.1445
# Epoch 198/200
# 24/24 [==============================] - 4s 146ms/step - loss: 0.1460
# Epoch 199/200
# 24/24 [==============================] - 4s 159ms/step - loss: 0.1439
# Epoch 200/200
# 24/24 [==============================] - 4s 166ms/step - loss: 0.1430

# %%
from keras.models import load_model
model = load_model('model.h5')

# %%
def make_inference_models():
    
    encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)
    
    decoder_state_input_h = tf.keras.layers.Input(shape=( 200 ,))
    decoder_state_input_c = tf.keras.layers.Input(shape=( 200 ,))
    
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    
    decoder_outputs, state_h, state_c = decoder_lstm(
        decoder_embedding , initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = tf.keras.models.Model(
        [decoder_inputs] + decoder_states_inputs,
        [decoder_outputs] + decoder_states)
    
    return encoder_model , decoder_model

# %%
def str_to_tokens( sentence : str ):
    words = sentence.lower().split()
    tokens_list = list()
    for word in words:
        tokens_list.append( input_features_dict[word] ) 
    return preprocessing.sequence.pad_sequences( [tokens_list] , maxlen=max_encoder_seq_length , padding='post')

# %%
enc_model , dec_model = make_inference_models()

for _ in range(10):
    states_values = enc_model.predict( str_to_tokens( input( 'Enter question : ' ) ) )
    empty_target_seq = np.zeros( ( 1 , 1 ) )
    empty_target_seq[0, 0] = target_features_dict['<START>']
    stop_condition = False
    decoded_translation = ''
    while not stop_condition :
        dec_outputs , h , c = dec_model.predict([ empty_target_seq ] + states_values )
        sampled_word_index = np.argmax( dec_outputs[0, -1, :] )
        sampled_word = reverse_target_features_dict[sampled_word_index]
        decoded_translation += " " + sampled_word
        
        if sampled_word == '<END>' or len(decoded_translation.split()) > max_decoder_seq_length:
            stop_condition = True
            
        empty_target_seq = np.zeros( ( 1 , 1 ) )  
        empty_target_seq[ 0 , 0 ] = sampled_word_index
        states_values = [ h , c ] 

    print( decoded_translation )

# %%
from keras.models import load_model
training_model = load_model('model.h5')

encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)
    
decoder_state_input_h = tf.keras.layers.Input(shape=( 200 ,))
decoder_state_input_c = tf.keras.layers.Input(shape=( 200 ,))

decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_embedding , initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = tf.keras.models.Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

def decode_response(test_input):
  states_values = encoder_model.predict(test_input)

  target_seq = np.zeros( ( 1 , 1 ) )
  target_seq[0, 0] = target_features_dict['<START>']
  stop_condition = False
  decoded_translation = ""
  while not stop_condition :
      dec_outputs , h , c = training_model.predict([ target_seq ] + states_values )

      sampled_word_index = np.argmax( dec_outputs[0, -1, :] )
      sampled_word = reverse_target_features_dict[sampled_word_index]
      decoded_translation += " " + sampled_word
      
      if sampled_word == '<END>' or len(decoded_translation.split()) > max_decoder_seq_length:
          stop_condition = True
          
      empty_target_seq = np.zeros( ( 1 , 1 ) )  
      empty_target_seq[ 0 , 0 ] = sampled_word_index
      states_values = [ h , c ] 

  return decoded_translation

# %%
def generate_response(input):
  input = clean_text(input)
  #tokens = re.findall(r"[\w']+|[^\s\w]", input)
  #input_matrix = np.zeros(
  #    (1, max_encoder_seq_length),
  #    dtype='int32')
  #for timestep, token in enumerate(tokens):
  #  if token in input_features_dict:
  #    input_matrix[0, timestep] = input_features_dict[token]
  #output = decode_response(input_matrix)
  output = decode_response(str_to_tokens(input))
  return output.replace("<START>","").replace("<END>","")


while True:
  reply = input()
  if reply == "STOP":
    break
  print(generate_response(reply))

# %%
def make_inference_models():
    
    encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)
    
    decoder_state_input_h = tf.keras.layers.Input(shape=( 200 ,))
    decoder_state_input_c = tf.keras.layers.Input(shape=( 200 ,))
    
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    
    decoder_outputs, state_h, state_c = decoder_lstm(
        decoder_embedding , initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = tf.keras.models.Model(
        [decoder_inputs] + decoder_states_inputs,
        [decoder_outputs] + decoder_states)
    
    return encoder_model , decoder_model

# %% [markdown]
# Legacy Code:

# %%
from tensorflow import keras
from keras.layers import Input, LSTM, Dense
from keras.models import Model

#Dimensionality
dimensionality = 256

#The batch size and number of epochs
batch_size = 10
epochs = 10

#Encoder
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder_lstm = LSTM(dimensionality, return_state=True)
encoder_outputs, state_hidden, state_cell = encoder_lstm(encoder_inputs)
encoder_states = [state_hidden, state_cell]

#Decoder
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(dimensionality, return_sequences=True, return_state=True)
decoder_outputs, decoder_state_hidden, decoder_state_cell = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

#Model
training_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

#Compiling
training_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'], sample_weight_mode='temporal')

#Training
training_model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size = batch_size, epochs = epochs, validation_split = 0.2)
training_model.save('training_model.h5')

# %%
from keras.models import load_model
training_model = load_model('training_model.h5')
encoder_inputs = training_model.input[0]
encoder_outputs, state_h_enc, state_c_enc = training_model.layers[2].output
encoder_states = [state_h_enc, state_c_enc]
encoder_model = Model(encoder_inputs, encoder_states)

latent_dim = 256
decoder_state_input_hidden = Input(shape=(latent_dim,))
decoder_state_input_cell = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_hidden, decoder_state_input_cell]
decoder_outputs, state_hidden, state_cell = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_hidden, state_cell]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

def decode_response(test_input):
  #Getting the output states to pass into the decoder
  states_value = encoder_model.predict(test_input)
  
  #Generating empty target sequence of length 1
  target_seq = np.zeros((1, 1, num_decoder_tokens))
  
  #Setting the first token of target sequence with the start token
  target_seq[0, 0, target_features_dict['<START>']] = 1.
  
  #A variable to store our response word by word
  decoded_sentence = ''
    
  stop_condition = False

  while not stop_condition:
    #Predicting output tokens with probabilities and states
    output_tokens, hidden_state, cell_state = decoder_model.predict([target_seq] + states_value)
    
    #Choosing the one with highest probability
    sampled_token_index = np.argmax(output_tokens[0, -1, :])
    sampled_token = reverse_target_features_dict[sampled_token_index]
    decoded_sentence += " " + sampled_token
    
    #Stop if hit max length or found the stop token
    if (sampled_token == '' or len(decoded_sentence) > max_decoder_seq_length):
      stop_condition = True
    
    #Update the target sequence
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, sampled_token_index] = 1.
    
    #Update states
    states_value = [hidden_state, cell_state]
  return decoded_sentence

# %%
class ChatBot:
  negative_responses = ("no", "nope", "nah", "naw", "not a chance", "sorry")
  exit_commands = ("quit", "pause", "exit", "goodbye", "bye", "later", "stop")
  
  #Method to start the conversation
  def start_chat(self):
    user_response = input("Hi, I'm a chatbot trained on random dialogs. Would you like to chat with me?\n")
    
    if user_response in self.negative_responses:
      print("Ok, have a great day!")
      return
    self.chat(user_response)
  
  #Method to handle the conversation
  def chat(self, reply):
    while not self.make_exit(reply):
      reply = input(self.generate_response(reply)+"\n")
    
  #Method to convert user input into a matrix
  def string_to_matrix(self, user_input):
    tokens = re.findall(r"[\w']+|[^\s\w]", user_input)
    user_input_matrix = np.zeros(
      (1, max_encoder_seq_length, num_encoder_tokens),
      dtype='float32')
    for timestep, token in enumerate(tokens):
      if token in input_features_dict:
        user_input_matrix[0, timestep, input_features_dict[token]] = 1.
    return user_input_matrix

  #Method that will create a response using seq2seq model we built
  def generate_response(self, user_input):
    input_matrix = self.string_to_matrix(user_input)  
    chatbot_response = decode_response(input_matrix)
    #Remove  and  tokens from chatbot_response
    chatbot_response = chatbot_response.replace("<START>",'')
    chatbot_response = chatbot_response.replace("<END>",'')
    return chatbot_response
  
  #Method to check for exit commands
  def make_exit(self, reply):
    for exit_command in self.exit_commands:
      if exit_command in reply:
        print("Ok, have a great day!")
        return True
    return False
  
chatbot = ChatBot()
chatbot.start_chat()

# %%
def generate_response(input):
  input = clean_text(input)
  tokens = re.findall(r"[\w']+|[^\s\w]", input)
  input_matrix = np.zeros(
      (1, max_encoder_seq_length, num_encoder_tokens),
      dtype='float32')
  for timestep, token in enumerate(tokens):
    if token in input_features_dict:
      input_matrix[0, timestep, input_features_dict[token]] = 1
  output = decode_response(input_matrix)
  return output.replace("<START>","").replace("<END>","")


while True:
  reply = input()
  if reply == "STOP":
    break
  print(generate_response(reply)+'\n')

# %%
def save_model(model):
  model.save('')
  return pick_model

# %%
def load_model():
  return model
